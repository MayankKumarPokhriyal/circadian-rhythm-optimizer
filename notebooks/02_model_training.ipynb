# %% [markdown]
# # 02 · Model Training and Evaluation
#
# End-to-end pipeline to: load processed MMASH data, generate circadian features, add solar context, train a CNN+BiGRU phase estimator, and visualize results.

# %%
# Setup imports and paths
import os, sys, json
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Ensure src is on path
root = Path('..').resolve() if (Path.cwd().name == 'notebooks') else Path('.')
sys.path.insert(0, str(root / 'src'))

DATA_PROCESSED = root / 'data' / 'processed' / 'all_users_merged.csv'
FEATURES_OUT = root / 'data' / 'features' / 'circadian_features.csv'
MODEL_PATH = root / 'model' / 'circadian_phase_estimator.pt'
FEATURES_OUT.parent.mkdir(parents=True, exist_ok=True)
: 
,
: { 
: 
 },
: [
1
,
,
,
,

: 
,
: { 
: 
 },
: [
2
,
,
,
41.9028
12.4964
,
,
,
,

: 
,
: { 
: 
 },
: [
3
,
,
,
,
,

: 
,
: { 
: 
 },
: [
4
,
,
,
,
,
,
2
5
,

,
,
,
,
10000
,
,
